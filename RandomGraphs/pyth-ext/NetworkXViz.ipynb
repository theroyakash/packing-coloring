# %%
# !pip3 install networkx\[default\]

# %%
# NetworkX visualization

from rich.console import Console
console = Console()

import networkx as nx
import matplotlib.pyplot as plt

# Generate a random graph with n nodes and probability p of edge creation
n = 10  # Number of nodes
p = 0.46  # Probability of edge creation

G = nx.gnp_random_graph(n, p)

# Add labels to nodes
labels = {node: str(node) for node in G.nodes()}

# Draw the graph
pos = nx.spring_layout(G)  # Layout algorithm (spring_layout is just an example)
nx.draw(G, pos, with_labels=True, labels=labels, node_size=700, node_color='skyblue', font_size=8, font_color='black', font_weight='bold', edge_color='gray')

# Show the plot
plt.show()

# %%
edges = [(1, 2),
(1, 3),
(1, 5),
(1, 6),
(1, 9),
(2, 8),
(3, 7),
(3, 10),
(4, 5),
]

# %%
for e in edges:
    console.print(e[0], e[1])
# Out:
# 1 2
# 1 3
# 1 5
# 1 6
# 1 9
# 2 8
# 3 7
# 3 10
# 4 5

# %%
with open("edges.txt", 'rb') as f:
    read_edges = [tuple(map(int, line.strip().split())) for line in f]

# %%
read_edges
# Out:
# [(1, 4),
#  (1, 6),
#  (1, 7),
#  (1, 9),
#  (1, 13),
#  (1, 14),
#  (1, 16),
#  (1, 17),
#  (1, 18),
#  (1, 20),
#  (2, 3),
#  (2, 4),
#  (2, 12),
#  (2, 15),
#  (2, 19),
#  (3, 8),
#  (4, 11),
#  (5, 6),
#  (8, 10)]

# %%
G = nx.Graph()
G.add_edges_from(read_edges)

nx.draw(G, with_labels=False, font_weight='bold', node_color='red', edge_color='gray', node_size=20)
plt.show()

# %% [markdown]
# ### Stats
# - Total Nodes: 300
# - Probability: 0.0216692
# - Edges: 299 (Tree)

# %%
with open("edges.txt", 'rb') as f:
    read_edges = [tuple(map(int, line.strip().split())) for line in f]

# %%
G = nx.Graph()
G.add_edges_from(read_edges)

nx.draw(G, with_labels=False, font_weight='bold', node_color='red', edge_color='gray', node_size=20)
plt.show()

# %% [markdown]
# ### Stats
# - Total Nodes: 50
# - Probability: 0.153513
# - Edges: 49 (Tree)

# %%
with open("edges.txt", 'rb') as f:
    read_edges = [tuple(map(int, line.strip().split())) for line in f]

# %%
G = nx.Graph()
G.add_edges_from(read_edges)

nx.draw(G, with_labels=False, font_weight='bold', node_color='red', edge_color='gray', node_size=20)
plt.show()

# %% [markdown]
# ### Stats
# - Total Nodes: 30
# - Probability: 0.163563
# - Edges: 29 (Tree)

# %%
with open("edges.txt", 'rb') as f:
    read_edges = [tuple(map(int, line.strip().split())) for line in f]

# %%
G = nx.Graph()
G.add_edges_from(read_edges)

nx.draw(G, with_labels=False, font_weight='bold', node_color='red', edge_color='gray', node_size=20)
plt.show()

# %% [markdown]
# ### Stats
# - Total Nodes: 130
# - Probability: 0.0950721
# - Edges: 129 (Tree)

# %%
with open("edges.txt", 'rb') as f:
    read_edges = [tuple(map(int, line.strip().split())) for line in f]

# %%
console.print(read_edges)
# Out:
# [
#     (1, 11),
#     (1, 17),
#     (1, 21),
#     (2, 8),
#     (2, 22),
#     (3, 4),
#     (3, 6),
#     (3, 8),
#     (3, 12),
#     (3, 13),
#     (3, 16),
#     (3, 17),
#     (3, 20),
#     (3, 23),
#     (4, 9),
#     (4, 10),
#     (4, 18),
#     (5, 9),
#     (7, 8),
#     (7, 14),
#     (7, 19),
#     (14, 15)
# ]

# %%
G = nx.Graph()
G.add_edges_from(read_edges)

nx.draw(G, with_labels=True, font_weight='bold', node_color='red', edge_color='black', node_size=1)
plt.show()
