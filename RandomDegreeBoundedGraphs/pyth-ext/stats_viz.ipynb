# %%
# !pip3 install pandas

# %%
four_degree_bound = "../stastistics/stats_4.csv"
five_degree_bound = "../stastistics/stats_5.csv"


import pandas as pd

# %%
df4 = pd.read_csv(four_degree_bound, sep = ',', index_col=False)

# %%
df4.head()
# Out:
#    CaseID  Nodes  Edges  Packing Coloring Start Time           Duration  \
# 0       1   6930   6929                            6   0.236011 seconds
# 1       2   9393   9392                           37   0.274033 seconds
# 2       3   9243   9242                            6    0.26134 seconds
# 3       4   6938   6937                            6   0.138271 seconds
# 4       5   5816   5815                           54  0.0885575 seconds
#
#    Max Reusable Color ID  Total Colors Used  Unique Colors Used n/x Ratio  \
# 0                    479                479                   0      n/14
# 1                    642                642                   0      n/14
# 2                    608                608                   0      n/15
# 3                    460                460                   0      n/15
# 4                    367                367                   0      n/15
#
#    Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves
# ...

# %%
df5 = pd.read_csv(five_degree_bound, sep = ',', index_col=False)

# %%
df5
# Out:
#    Case ID  Nodes  Edges  Starting Node           Duration  Total Colors Used  \
# 0        1   6219   6218              8    0.13859 seconds                402
# 1        2   7528   7527             11    0.18179 seconds                495
# 2        3   7129   7128              2    0.16021 seconds                477
# 3        4   8747   8746              7    0.25595 seconds                621
# 4        5   5872   5871             48   0.107242 seconds                412
# 5        6   5661   5660              4  0.0987107 seconds                402
# 6        7   7275   7274              1   0.171437 seconds                517
# 7        8   9373   9372             18   0.261865 seconds                608
# 8        9   8469   8468             10    0.23856 seconds                580
# 9       10   6082   6081              9   0.110259 seconds                408
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves
# ...

# %%
ten_degree_bound = "../stastistics/stats_10.csv"
df10 = pd.read_csv(ten_degree_bound, sep = ',', index_col=False)

df10
# Out:
#    Case ID  Nodes  Edges  Starting Node          Duration  Total Colors Used  \
# 0        1   6968   6967              6  0.144332 seconds                454
# 1        2   9943   9942             14  0.318606 seconds                617
# 2        3   9635   9634             18  0.290576 seconds                629
# 3        4   6892   6891             26  0.158339 seconds                462
# 4        5   8047   8046             14  0.200834 seconds                545
# 5        6   8073   8072             15  0.215422 seconds                545
# 6        7   7859   7858            118  0.191214 seconds                512
# 7        8   6705   6704             15  0.123045 seconds                436
# 8        9   8103   8102             37  0.221566 seconds                561
# 9       10   6698   6697             12  0.130773 seconds                446
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves
# ...

# %% [markdown]
# ### 50000 - 100,000 Nodes
# Stats for graphs with 50,000 to 100,000 nodes. Degree bound is set to 4.

# %%
df_50_100 = pd.read_csv("../stastistics/stats_50_100.csv", sep = ',', index_col=False)
df_50_100
# Out:
#    Case ID  Nodes  Edges  Starting Node         Duration  Total Colors Used  \
# 0        1  93232  93231              1  38.6065 seconds               6084
# 1        2  59529  59528             23   15.868 seconds               3842
# 2        3  93377  93376            325  36.1935 seconds               5967
# 3        4  88866  88865             68  31.9109 seconds               5703
# 4        5  52332  52331             27  10.8482 seconds               3357
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves
# 0      n/15          55619          17328      59.6566%         46611
# 1      n/15          35530          11111      59.6852%         29755
# 2      n/15          55639          17456      59.5853%         46563
# 3      n/15          53018          16569      59.6606%         44465
# 4      n/15          31180           9765      59.5811%         26108

# %%
df_50_100['Total Leaves to Color 1 Count Ratio'] = df_50_100['Total Leaves'] / df_50_100['Color 1 Count']
df_50_100
# Out:
#    Case ID  Nodes  Edges  Starting Node         Duration  Total Colors Used  \
# 0        1  93232  93231              1  38.6065 seconds               6084
# 1        2  59529  59528             23   15.868 seconds               3842
# 2        3  93377  93376            325  36.1935 seconds               5967
# 3        4  88866  88865             68  31.9109 seconds               5703
# 4        5  52332  52331             27  10.8482 seconds               3357
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves  \
# 0      n/15          55619          17328      59.6566%         46611
# 1      n/15          35530          11111      59.6852%         29755
# 2      n/15          55639          17456      59.5853%         46563
# 3      n/15          53018          16569      59.6606%         44465
# 4      n/15          31180           9765      59.5811%         26108
#
#    Total Leaves to Color 1 Count Ratio
# 0                             0.838041
# ...

# %%
df10['Total Leaves to Color 1 Count Ratio'] = df10['Total Leaves'] / df10['Color 1 Count']

# %%
df10
# Out:
#    Case ID  Nodes  Edges  Starting Node          Duration  Total Colors Used  \
# 0        1   6968   6967              6  0.144332 seconds                454
# 1        2   9943   9942             14  0.318606 seconds                617
# 2        3   9635   9634             18  0.290576 seconds                629
# 3        4   6892   6891             26  0.158339 seconds                462
# 4        5   8047   8046             14  0.200834 seconds                545
# 5        6   8073   8072             15  0.215422 seconds                545
# 6        7   7859   7858            118  0.191214 seconds                512
# 7        8   6705   6704             15  0.123045 seconds                436
# 8        9   8103   8102             37  0.221566 seconds                561
# 9       10   6698   6697             12  0.130773 seconds                446
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves  \
# ...

# %%
ddf = pd.read_csv("../stastistics/stats.csv", sep = ',', index_col=False)

# %%
ddf
# Out:
#    Case ID  Nodes  Edges  Starting Node         Duration  Total Colors Used  \
# 0        1  88781  88780              9  32.8491 seconds               5766
# 1        2  67058  67057              8  17.5949 seconds               4290
# 2        3  95175  95174             18  36.9358 seconds               6066
# 3        4  95147  95146             39  37.2082 seconds               6133
# 4        5  84382  84381             12  28.4715 seconds               5318
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves
# 0      n/15          52957          16569       59.649%         44384
# 1      n/15          39967          12487      59.6006%         33500
# 2      n/15          56766          17767      59.6438%         47558
# 3      n/15          56771          17720      59.6666%         47531
# 4      n/15          50309          15712      59.6205%         42156
