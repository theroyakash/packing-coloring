# %%
import pandas as pd

# %%
deg_three_bound = pd.read_csv("../stastistics/stats_3.csv", sep=',', index_col=False)
deg_three_bound["leaves/ratio"] = deg_three_bound["Total Leaves"] / deg_three_bound["Nodes"] * 100
deg_three_bound
# Out:
#    Case ID  Nodes  Edges  Starting Node          Duration  Total Colors Used  \
# 0        1  35843  35842             33  0.532999 seconds                394
# 1        2  47575  47574             18  0.792474 seconds                511
# 2        3  29586  29585             13   0.31961 seconds                325
# 3        4  26204  26203             15   0.25451 seconds                299
# 4        5  37777  37776             29  0.588651 seconds                431
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves  \
# 0      n/90          19803           7733      55.2493%         13636
# 1      n/93          26268          10307      55.2139%         18167
# 2      n/91          16342           6390      55.2356%         11270
# 3      n/87          14495           5613       55.316%         10018
# 4      n/87          20849           8117      55.1897%         14452
#
#    leaves/ratio
# 0     38.043691
# 1     38.186022
# 2     38.092341
# ...

# %%
deg_three_bound_10_cases = pd.read_csv("../stastistics/stats_10-3.csv", sep=',', index_col=False)
deg_three_bound_10_cases["leaves/ratio"] = deg_three_bound_10_cases["Total Leaves"] / deg_three_bound_10_cases["Nodes"] * 100
deg_three_bound_10_cases
# Out:
#    Case ID  Nodes  Edges  Starting Node           Duration  Total Colors Used  \
# 0        1  44106  44105              9   0.664595 seconds                460
# 1        2  29399  29398             13   0.320329 seconds                324
# 2        3  19829  19828             24   0.143609 seconds                234
# 3        4  10323  10322              3  0.0394277 seconds                141
# 4        5  13796  13795             15  0.0722418 seconds                169
# 5        6  25038  25037             49   0.214447 seconds                262
# 6        7  49302  49301             29   0.907608 seconds                509
# 7        8  16802  16801              1   0.147636 seconds                210
# 8        9  38467  38466             16   0.564482 seconds                408
# 9       10  10752  10751             21  0.0431531 seconds                143
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves  \
# ...

# %%
deg_four_bound = pd.read_csv("../stastistics/stats_10-4.csv", sep=',', index_col=False)
deg_four_bound["leaves/ratio"] = deg_four_bound["Total Leaves"] / deg_four_bound["Nodes"] * 100
deg_four_bound
# Out:
#    Case ID  Nodes  Edges  Starting Node          Duration  Total Colors Used  \
# 0        1  30567  30566              4   1.74976 seconds               1148
# 1        2  45313  45312              2   3.75265 seconds               1676
# 2        3  34129  34128              4   1.85074 seconds               1211
# 3        4  18509  18508             23  0.547518 seconds                694
# 4        5  32707  32706             15   1.94331 seconds               1229
# 5        6  47345  47344              1   3.95162 seconds               1776
# 6        7  19997  19996             11   0.73358 seconds                804
# 7        8  27281  27280              2    1.2939 seconds               1025
# 8        9  49136  49135             87    4.4364 seconds               1841
# 9       10  16974  16973             31  0.537599 seconds                656
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves  \
# ...

# %%
deg_five_bound = pd.read_csv("../stastistics/stats_10-5.csv", sep=',', index_col=False)
deg_five_bound["leaves/ratio"] = deg_five_bound["Total Leaves"] / deg_five_bound["Nodes"] * 100
deg_five_bound
# Out:
#    Case ID  Nodes  Edges  Starting Node         Duration  Total Colors Used  \
# 0        1  27696  27695             11  2.12347 seconds               1404
# 1        2  47984  47983             38  6.20615 seconds               2482
# 2        3  38448  38447              9  4.23243 seconds               1957
# 3        4  21553  21552              1  1.24437 seconds               1148
# 4        5  37684  37683              3  4.31422 seconds               1945
# 5        6  24029  24028             10   1.7243 seconds               1249
# 6        7  46103  46102             10   6.8412 seconds               2342
# 7        8  30406  30405             29  2.39924 seconds               1572
# 8        9  38109  38108             14  3.85268 seconds               1924
# 9       10  32804  32803              3  2.86852 seconds               1661
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves  \
# ...

# %%
d6b = pd.read_csv("../stastistics/stats_10-6.csv", sep=',', index_col=False)
d6b["leaves/ratio"] = d6b["Total Leaves"] / d6b["Nodes"] * 100
d6b
# Out:
#    Case ID  Nodes  Edges  Starting Node          Duration  Total Colors Used  \
# 0        1  42364  42363             51    5.5468 seconds               2446
# 1        2  49597  49596             30   8.06327 seconds               2919
# 2        3  38312  38311              6   4.71983 seconds               2179
# 3        4  36736  36735             13   4.31372 seconds               2148
# 4        5  46077  46076              4   7.25746 seconds               2707
# 5        6  11036  11035             42  0.331053 seconds                660
# 6        7  14492  14491             13  0.595155 seconds                864
# 7        8  23894  23893              8   1.99161 seconds               1406
# 8        9  15478  15477              5  0.672481 seconds                916
# 9       10  49603  49602             23    8.9231 seconds               2956
#
#   n/x Ratio  Color 1 Count  Color 2 Count Color 1 Ratio  Total Leaves  \
# ...

# %%
d4b_small = pd.read_csv("../stastistics/stats.csv", sep=',', index_col=False)
d4b_small["leaves/ratio"] = d4b_small["Total Leaves"] / d4b_small["Nodes"] * 100

d4b_small
# Out:
#     Case ID  Nodes  Edges  Starting Node             Duration  \
# 0         1     28     27             21   5.1375e-05 seconds
# 1         2     20     19              3   0.00019975 seconds
# 2         3     28     27              3   6.6833e-05 seconds
# 3         4     29     28             18   3.7416e-05 seconds
# 4         5     22     21             18   3.7833e-05 seconds
# 5         6     20     19              9   5.6625e-05 seconds
# 6         7     29     28              6   4.9166e-05 seconds
# 7         8     20     19              3   3.1875e-05 seconds
# 8         9     30     29             10  0.000110209 seconds
# 9        10     20     19              6   4.9333e-05 seconds
# 10       11     25     24              3   7.8125e-05 seconds
# 11       12     21     20              7   5.5083e-05 seconds
# 12       13     29     28              5   4.4834e-05 seconds
# 13       14     27     26              8   5.4125e-05 seconds
# ...
